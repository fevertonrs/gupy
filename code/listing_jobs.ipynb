# %%
import requests

url = "https://api.gupy.io/api/v1/jobs?fields=all&perPage=10&page=1"

headers = {
    "accept": "application/json",
    "authorization": "Bearer e82944c6-7d78-4b8a-875d-75a7e2a45f17"
}

response = requests.get(url, headers=headers)

dados = response.text 

print(dados)
# Out:
# {"results":[{"id":3484949,"code":"VBT","name":"Não encontrou uma vaga pra você? Deixe seu currículo aqui!","status":"published","type":"vacancy_type_talent_pool","publicationType":"external","numVacancies":1,"departmentId":477023,"departmentName":"Banco de Talentos","roleId":704242,"roleName":"Banco de Talentos","subsidiaryId":null,"subsidiaryName":null,"createdAt":"2022-11-17T17:41:30.542Z","updatedAt":"2023-08-21T18:32:22.886Z","hiringDeadline":"2023-12-31","description":"<p class=\"ql-align-justify\">Tudo o que fazemos só é possível com as pessoas no centro, por isso, somos comprometidos com a inclusão e valorizamos as diferentes formas de contribuir com a criação de um amanhã mais positivo. Estimulamos a candidatura de pessoas com deficiência e também de representantes das diferentes etnias e identidades de gênero.&nbsp;</p><p class=\"ql-align-justify\">Confira nossas vagas e venha fazer parte da nossa sinergia.&nbsp;&nbsp;&nbsp;&nbsp;</p><p class=\"ql-align-justify\">Não encontr
# ...

# %%
import pandas as pd
import json

pd.set_option('display.max_columns', None)

js = json.loads(dados)

df = pd.json_normalize(js['results'])

df

#print(dados[0])
# Out:
#         id           code                                               name  \
# 0  3484949            VBT  Não encontrou uma vaga pra você? Deixe seu cur...
# 1  3542583  52615-3542583                            Analista Tributário II
# 2  3542766  52615-3542766                                     Analista Adm I
# 3  3543019  52615-3543019                                     Analista Adm I
# 4  3578132  52615-3578132                              Analista Comercial II
# 5  3619247  52615-3619247   Consultora | Consultor Segurança da Informação I
# 6  3671782  52615-3671782                              Analista Comercial II
# 7  3681977  52615-3681977                  Gerente de Remuneração e Serviços
# 8  3683719  52615-3683719               Analista Planejamento Energético III
# 9  3688701  52615-3688701            Consultora | Consultor Gestao Energia I
#
#       status                      type publicationType  numVacancies  \
# ...
